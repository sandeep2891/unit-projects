# %% [markdown]
# # Project 4
#
# In this project, you will summarize and present your analysis from Projects 1-3.

# %% [markdown]
# ### Intro: Write a problem Statement/ Specific Aim for this project

# %% [markdown]
# Answer: Using UCLA admissions dataset to determine if there is an association between graduate school admission and the prestige of a student's undergraduate school.

# %% [markdown]
# ### Dataset:  Write up a description of your data and any cleaning that was completed

# %% [markdown]
# Answer: We initially had 400 observations in our dataset. After dropping those datapoints which had missing values we are left with 397 observations.
#
# Here admit which is a binary variable is our dependent variable. We also have 3 more independent variables which include gre which a discrete variable ranging from (220-800), gpa which a continous variable ranging from (2.26-4.00) and  prestige of applicants previous school which is a categorical variable

# %% [markdown]
# ### Demo: Provide a table that explains the data by admission status

# %% [markdown]
# ##### Mean (STD) or counts by admission status for each variable
#
# | Not Admitted | Admitted
# ---| ---|---
# GPA | mean-3.345404  | mean-3.489206
# GRE |mean-573.579  | mean-618.897
# Prestige 1 | 7.5% | 8.3%
# Prestige 2 | 23.9% | 13.3%
# Prestige 3 |23.4% | 7.1%
# Prestige 4 |13.8% | 3%

# %% [markdown]
# ### Methods: Write up the methods used in your analysis

# %% [markdown]
# Answer: for our analysis we used logistic regression methood from statsmodels. This was to caluclate weather the student will get admit or not.

# %% [markdown]
# ### Results: Write up your results

# %% [markdown]
# Answer: Given the same GPA and GRE, student from a school of prestige 1 has a higher likelihood of getting admitted to grad school then a student of prestige 2 or 3 or 4.
# Prestige rankings:
# 1>2>3>4

# %% [markdown]
# ### Visuals: Provide a table or visualization of these results

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Discussion: Write up your discussion and future steps

# %% [markdown]
# Answer: Our findings suggest that students from prestige 1 school have the higher probability of getting admitted. It might be interested to see if students from prestige 1 schools also have high gpa and score high in gre.
